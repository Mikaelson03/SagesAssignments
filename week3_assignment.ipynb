# %% [markdown]
# <h3 style="color: purple>IMPORTS</h3>

# %%
from dotenv import load_dotenv
import requests
load_dotenv()
import os
CG_APIKEY = os.getenv("CGAPIKEY")

header = {"x-cg-demo-api-key": CG_APIKEY}
url = "https://api.coingecko.com/api/v3/coins/markets"
params = {"vs_currency": "usd"}

response = requests.get(url, headers=header, params=params)
token_data = response.json()
print(token_data)
# Out:
# [{'id': 'bitcoin', 'symbol': 'btc', 'name': 'Bitcoin', 'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400', 'current_price': 66773, 'market_cap': 1336015609571, 'market_cap_rank': 1, 'fully_diluted_valuation': 1336015609571, 'total_volume': 24424060720, 'high_24h': 67186, 'low_24h': 65885, 'price_change_24h': 672.16, 'price_change_percentage_24h': 1.01686, 'market_cap_change_24h': 13869981545, 'market_cap_change_percentage_24h': 1.04905, 'circulating_supply': 20008381.0, 'total_supply': 20008381.0, 'max_supply': 21000000.0, 'ath': 126080, 'ath_change_percentage': -47.03886, 'ath_date': '2025-10-06T18:57:42.558Z', 'atl': 67.81, 'atl_change_percentage': 98372.68679, 'atl_date': '2013-07-06T00:00:00.000Z', 'roi': None, 'last_updated': '2026-03-28T21:21:00.579Z'}, {'id': 'ethereum', 'symbol': 'eth', 'name': 'Ethereum', 'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628', 'current_price': 2019.19, 'market_cap': 243767507456, 'market_cap_rank': 2, 'fully_diluted_valuation': 243767507456, 'total_volume': 8394436844, 'high_24h': 2032.74, 'low_24h': 1980.15, 'price_change_24h': 31.82, 'price_change_percentage_24h': 1.60087, 'market_cap_change_24h': 3891896985, 'market_cap_change_percentage_24h': 1.62246, 'circulating_supply': 120691485.3866902, 'total_supply': 120691485.3866902, 'max_supply': None, 'ath': 4946.05, 'ath_change_percentage': -59.17577, 'ath_date': '2025-08-24T19:21:03.333Z', 'atl': 0.432979, 'atl_change_percentage': 466247.53195, 'atl_date': '2015-10-20T00:00:00.000Z', 'roi': {'times': 39.427099139017955, 'currency': 'btc', 'percentage': 3942.7099139017955}, 'last_updated': '2026-03-28T21:21:00.659Z'}, {'id': 'tether', 'symbol': 'usdt', 'name': 'Tether', 'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661', 'current_price': 0.999212, 'market_cap': 184073251840, 'market_cap_rank': 3, 'fully_diluted_valuation': 189535938039, 'total_volume': 39456583967, 'high_24h': 0.999411, 'low_24h': 0.999218, 'price_change_24h': -2.4160912527993e-05, 'price_change_percentage_24h': -0.00242, 'market_cap_change_24h': 623863, 'market_cap_change_percentage_24h': 0.00034, 'circulating_supply': 184216554250.0974, 'total_supply': 189683493191.2362, 'max_supply': None, 'ath': 1.32, 'ath_change_percentage': -24.4792, 'ath_date': '2018-07-24T00:00:00.000Z', 'atl': 0.572521, 'atl_change_percentage': 74.52847, 'atl_date': '2015-03-02T00:00:00.000Z', 'roi': None, 'last_updated': '2026-03-28T21:19:53.501Z'}, {'id': 'binancecoin', 'symbol': 'bnb', 'name': 'BNB', 'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970', 'current_price': 616.68, 'market_cap': 84090573883, 'market_cap_rank': 4, 'fully_diluted_valuation': 84090573883, 'total_volume': 656917872, 'high_24h': 617.65, 'low_24h': 609.54, 'price_change_24h': 5.4, 'price_change_percentage_24h': 0.88352, 'market_cap_change_24h': 738276800, 'market_cap_change_percentage_24h': 0.88573, 'circulating_supply': 136357265.82, 'total_supply': 136357265.82, 'max_supply': 200000000.0, 'ath': 1369.99, 'ath_change_percentage': -54.98669, 'ath_date': '2025-10-13T08:41:24.131Z', 'atl': 0.0398177, 'atl_change_percentage': 1548654.95243, 'atl_date': '2017-10-19T00:00:00.000Z', 'roi': None, 'last_updated': '2026-03-28T21:21:00.561Z'}, {'id': 'ripple', 'symbol': 'xrp', 'name': 'XRP', 'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442', 'current_price': 1.34, 'market_cap': 82488074843, 'market_cap_rank': 5, 'fully_diluted_valuation': 134447526159, 'total_volume': 1278120125, 'high_24h': 1.35, 'low_24h': 1.32, 'price_change_24h': 0.01594067, 'price_change_percentage_24h': 1.19965, 'market_cap_change_24h': 975885997, 'market_cap_change_percentage_24h': 1.19723, 'circulating_supply': 61344583754.0, 'total_supply': 99985695443.0, 'max_supply': 100000000000.0, 'ath': 3.65, 'ath_change_percentage': -63.12175, 'ath_date':  ...
